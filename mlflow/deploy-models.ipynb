# %% [markdown]
# ## Quickstart: Compare runs, choose a model, and deploy it to REST API
#
# In this quickstart, we will:
# - Run a hyperparameter tuning sweep on a training script.
# - Compare the results of the runs in the MlFlow UI.
# - Choose the best run and register it as a model.
# - Deploy the model to a REST API.
# - Build a container image suitable for deployment to a cloud platform.

# %% [markdown]
# ![MlFlow Tracking](images/mlflow_tracking.png)

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
# Load the dataset
data = pd.read_csv("https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv", sep=";")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
def train_valid_test_split(data):
    """Split the data into training and validation sets.
    """
    # Split the data into training, validation and test sets
    train, test = train_test_split(data, test_size=0.2, random_state=42)

    # Get training set
    train_x = train.drop(columns=["quality"], axis=1).values
    train_y = train["quality"].values.ravel()

    # Split training set into training and validation sets
    train_x, val_x, train_y, val_y = train_test_split(
        train_x,
        train_y,
        test_size=0.2,
        random_state=42,
    )

    # Get test set
    test_x = test.drop(columns=["quality"], axis=1).values
    test_y = test["quality"].values.ravel()

    return train_x, train_y, val_x, val_y, test_x, test_y

# %%
from keras import Input
# Create ANN model
from keras.api.models import Sequential
from keras.src.layers import Normalization
from keras.api.layers import Dense

class Model:
    def __init__(
            self,
            training_set,
            signature,
            params,
            epochs=3,
    ):
        self.data = data
        self.params = params
        self.train_x = training_set[0]
        self.train_y = training_set[1]
        self.val_x = training_set[2]
        self.val_y = training_set[3]
        self.test_x = training_set[4]
        self.test_y = training_set[5]
        self.signature = signature
        self.epochs = epochs
        self.model = self.create_model()

    def create_model(self):
        """
        Create a Sequential model with the given hyperparameters.
        :return: Compiled Keras model
        """
        # Create normalization layer first
        normalizer = Normalization()

        # Adapt the normalizer to the training data
        normalizer.adapt(self.train_x)

        # Build the model
        model = Sequential()
        model.add(Input(shape=(self.train_x.shape[1],)))
        model.add(normalizer)
        model.add(Dense(64, activation='relu'))
        model.add(Dense(1))

        model.compile(
            loss='mean_squared_error',
            metrics=[keras.metrics.RootMeanSquaredError()],
            optimizer=keras.optimizers.SGD(
                learning_rate=self.params['lr'],
                momentum=self.params['momentum'],
            ),
        )

        return model

    def track_training(self):
        """Track the training process using MLflow."""

        with mlflow.start_run(nested=True):
            self.model.fit(
                self.train_x,
                self.train_y,
                validation_data=(self.val_x, self.val_y),
                epochs=self.epochs,
                batch_size=64,
            )

            # Evaluate the model
            eval_result = self.model.evaluate(self.val_x, self.val_y, batch_size=64)
            eval_rmse = eval_result[1]

            # Log parameters and metrics
            mlflow.log_params(self.params)
            mlflow.log_metric("rmse", eval_rmse)

            # Log the model
            mlflow.keras.log_model(
                model=self.model,
                artifact_path="ann-model",
                signature=self.signature,
            )

        return {"loss": eval_rmse, "status": STATUS_OK, "model": self.model}

# %%
# Split the data into training, validation and test sets
split_data = train_valid_test_split(data)

# Get training features and labels
train_x = split_data[0]
train_y = split_data[1]

# Get signature
signature = infer_signature(train_x, train_y)

# %%
def objective(params):
    """
    Objective function for hyperparameter tuning.
    :param params: Hyperparameters
    :return: Dictionary with loss and status
    """
    model = Model(split_data, signature, params)
    return model.track_training()

# %%
# Define the hyperparameter space
params = {
    "lr": hp.loguniform("lr", np.log(1e-5), np.log(1e-1)),
    "momentum": hp.uniform("momentum", 0, 1),
}
params
# Out:
# {'lr': <hyperopt.pyll.base.Apply at 0x2d8927170>,
#  'momentum': <hyperopt.pyll.base.Apply at 0x2d8927230>}

# %%
# Set mlflow experiment
mlflow.set_experiment("/white_wine_quality")

with mlflow.start_run():
    # Perform hyperparameter tuning

    # Create a Trials object to store the results
    trials = Trials()

    # Perform hyperparameter tuning using Hyperopt
    best = fmin(
        fn=objective,
        space=params,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials,
    )

    # Fetch details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best hyperparameters and loss
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])

    # Log the model
    mlflow.keras.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and loss
    print(f"Best parameters: {best}")
    print(f"Best rmse: {best_run["loss"]}")
# Out:
# 2025/04/30 08:48:07 INFO mlflow.tracking.fluent: Experiment with name '/white_wine_quality' does not exist. Creating a new experiment.
# Epoch 1/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - loss: 37.9334 - root_mean_squared_error: 6.1590
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.7396 - root_mean_squared_error: 6.1432
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 37.6098 - root_mean_squared_error: 6.1327
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 37.7330 - root_mean_squared_error: 6.1427
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 37.6436 - root_mean_squared_error: 6.1354
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 37.7937 - root_mean_squared_error: 6.1476
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 37.8157 - root_mean_squared_error: 6.1494
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.1777 - root_mean_squared_error: 6.0141 - val_loss: 30.9473 - val_root_mean_squared_error: 5.5630
#
# Epoch 2/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.4714 - root_mean_squared_error: 5.6984
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 32.1069 - root_mean_squared_error: 5.6662
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.8107 - root_mean_squared_error: 5.6400
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.1379 - root_mean_squared_error: 5.6400
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 31.8328 - root_mean_squared_error: 5.6400
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 31.6525 - root_mean_squared_error: 5.6259
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - loss: 31.4343 - root_mean_squared_error: 5.5981
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 31.5460 - root_mean_squared_error: 5.6064
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 31.3424 - root_mean_squared_error: 5.5981
# 10/49 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 31.2444 - root_mean_squared_error: 5.5893
# 11/49 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - loss: 31.1688 - root_mean_squared_error: 5.5825
# 12/49 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 31.1034 - root_mean_squared_error: 5.5706
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 29.1891 - root_mean_squared_error: 5.4013 - val_loss: 24.7582 - val_root_mean_squared_error: 4.9758
#
# Epoch 3/3
#
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 23.7243 - root_mean_squared_error: 4.8704
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.1858 - root_mean_squared_error: 4.8704
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 23.8296 - root_mean_squared_error: 4.8773
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - loss: 23.7896 - root_mean_squared_error: 4.8733
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 23.7505 - root_mean_squared_error: 4.8733
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 23.7399 - root_mean_squared_error: 4.8719
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 23.7369 - root_mean_squared_error: 4.8719
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 23.7026 - root_mean_squared_error: 4.8684
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - loss: 23.6528 - root_mean_squared_error: 4.8592
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.8935 - root_mean_squared_error: 4.7844 - val_loss: 19.7601 - val_root_mean_squared_error: 4.4452
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.2960 - root_mean_squared_error: 4.3927
#  2/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.2152 - root_mean_squared_error: 4.3835
#  3/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.4962 - root_mean_squared_error: 4.4326
#  4/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.6501 - root_mean_squared_error: 4.4326
#  6/13 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 19.7750 - root_mean_squared_error: 4.4467
#  5/13 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 19.7556 - root_mean_squared_error: 4.4444
#  7/13 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 19.7723 - root_mean_squared_error: 4.4464
#  9/13 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 19.7883 - root_mean_squared_error: 4.4482
#  8/13 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 19.7799 - root_mean_squared_error: 4.4482
# 10/13 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 19.7826 - root_mean_squared_error: 4.4476
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7722 - root_mean_squared_error: 4.4465
#
# Epoch 1/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - loss: 33.6557 - root_mean_squared_error: 5.8014
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.9861 - root_mean_squared_error: 5.7431
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.8968 - root_mean_squared_error: 5.7354
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.7104 - root_mean_squared_error: 5.7191
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.5443 - root_mean_squared_error: 5.7045
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.3770 - root_mean_squared_error: 5.6898
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2611 - root_mean_squared_error: 5.6796
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.1304 - root_mean_squared_error: 5.6680
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.9940 - root_mean_squared_error: 5.6559
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.4711 - root_mean_squared_error: 5.1335 - val_loss: 11.5763 - val_root_mean_squared_error: 3.4024
#
# Epoch 2/3
#
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 10.6636 - root_mean_squared_error: 3.2650
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.2803 - root_mean_squared_error: 3.2063
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 10.7021 - root_mean_squared_error: 3.2711
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 10.7380 - root_mean_squared_error: 3.2766
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 10.8184 - root_mean_squared_error: 3.2962
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 10.8781 - root_mean_squared_error: 3.2979
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 10.8668 - root_mean_squared_error: 3.2962
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 10.8786 - root_mean_squared_error: 3.2980
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 10.8491 - root_mean_squared_error: 3.2936
# 10/49 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 10.8154 - root_mean_squared_error: 3.2884
# 11/49 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 10.7685 - root_mean_squared_error: 3.2812
# 13/49 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 10.6837 - root_mean_squared_error: 3.2682
# 12/49 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 10.7263 - root_mean_squared_error: 3.2748
# 14/49 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 10.6401 - root_mean_squared_error: 3.2615
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 8.9563 - root_mean_squared_error: 2.9848 - val_loss: 4.4348 - val_root_mean_squared_error: 2.1059
#
# Epoch 3/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0482 - root_mean_squared_error: 2.0120
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 3.9559 - root_mean_squared_error: 1.9888
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 4.0058 - root_mean_squared_error: 1.9989
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 4.0195 - root_mean_squared_error: 2.0013
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 4.0089 - root_mean_squared_error: 2.0013
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 3.9967 - root_mean_squared_error: 1.9991
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 3.9959 - root_mean_squared_error: 2.0004
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 3.9826 - root_mean_squared_error: 1.9859
# 13/49 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - loss: 3.9087 - root_mean_squared_error: 1.9743
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - loss: 4.0018 - root_mean_squared_error: 1.9799
# 14/49 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 3.8989 - root_mean_squared_error: 1.9743
# 11/49 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 3.9445 - root_mean_squared_error: 1.9743
# 12/49 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 3.9209 - root_mean_squared_error: 1.9743
# 10/49 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 3.9379 - root_mean_squared_error: 1.9743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - loss: 3.4599 - root_mean_squared_error: 1.8578 - val_loss: 2.8565 - val_root_mean_squared_error: 1.6901
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5227 - root_mean_squared_error: 1.5883
#  2/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5598 - root_mean_squared_error: 1.5999
#  3/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6046 - root_mean_squared_error: 1.6137
#  4/13 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 2.6084 - root_mean_squared_error: 1.6149
#  5/13 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 2.6138 - root_mean_squared_error: 1.6166
#  7/13 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 2.5767 - root_mean_squared_error: 1.6050
#  6/13 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 2.5944 - root_mean_squared_error: 1.6106
#  8/13 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 2.6473 - root_mean_squared_error: 1.6260
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7611 - root_mean_squared_error: 1.6605
#
# Epoch 1/3
#
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 33.3991 - root_mean_squared_error: 5.7756
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - loss: 35.7584 - root_mean_squared_error: 5.9798
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 31.0091 - root_mean_squared_error: 5.5575
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 28.7044 - root_mean_squared_error: 5.3352
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 26.6180 - root_mean_squared_error: 5.1230
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 24.7886 - root_mean_squared_error: 4.9284
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 23.2192 - root_mean_squared_error: 4.7551
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7569 - root_mean_squared_error: 2.6046 - val_loss: 1.1277 - val_root_mean_squared_error: 1.0619
#
# Epoch 2/3
#
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 1.0825 - root_mean_squared_error: 1.0402
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0382 - root_mean_squared_error: 1.0402
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 1.0590 - root_mean_squared_error: 1.0287
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 1.0856 - root_mean_squared_error: 1.0418
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 1.0447 - root_mean_squared_error: 1.0160
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 1.0331 - root_mean_squared_error: 1.0160
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - loss: 1.0285 - root_mean_squared_error: 1.0138
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 1.0304 - root_mean_squared_error: 1.0148
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 1.0274 - root_mean_squared_error: 1.0133
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.9115 - root_mean_squared_error: 0.9541 - val_loss: 0.7640 - val_root_mean_squared_error: 0.8741
#
# Epoch 3/3
#
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.6859 - root_mean_squared_error: 0.8281
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 0.6811 - root_mean_squared_error: 0.8252
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.6782 - root_mean_squared_error: 0.8281
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6920 - root_mean_squared_error: 0.8319
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.6789 - root_mean_squared_error: 0.8265
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.6832 - root_mean_squared_error: 0.8265
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.6853 - root_mean_squared_error: 0.8278
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.6790 - root_mean_squared_error: 0.8237
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.6787 - root_mean_squared_error: 0.8205
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.6617 - root_mean_squared_error: 0.8134 - val_loss: 0.6256 - val_root_mean_squared_error: 0.7909
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6496 - root_mean_squared_error: 0.8060
#  2/13 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.6180 - root_mean_squared_error: 0.7858
#  3/13 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.6269 - root_mean_squared_error: 0.7915
#  4/13 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.6236 - root_mean_squared_error: 0.7895
#  5/13 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.6268 - root_mean_squared_error: 0.7916
#  6/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6206 - root_mean_squared_error: 0.7876
#  7/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6122 - root_mean_squared_error: 0.7821
#  8/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6117 - root_mean_squared_error: 0.7819
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6124 - root_mean_squared_error: 0.7824
#
# Epoch 1/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - loss: 42.7457 - root_mean_squared_error: 6.5380
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38.8166 - root_mean_squared_error: 6.2223
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.3481 - root_mean_squared_error: 5.9249
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2008 - root_mean_squared_error: 5.3855
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 29.6011 - root_mean_squared_error: 5.3855
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25.9299 - root_mean_squared_error: 5.0161
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27.5155 - root_mean_squared_error: 5.1769
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1458 - root_mean_squared_error: 2.8402 - val_loss: 0.6944 - val_root_mean_squared_error: 0.8333
#
# Epoch 2/3
#
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - loss: 0.5921 - root_mean_squared_error: 0.7680
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5178 - root_mean_squared_error: 0.7680
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.6308 - root_mean_squared_error: 0.7925
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.6496 - root_mean_squared_error: 0.8044
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.6632 - root_mean_squared_error: 0.8132
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.6535 - root_mean_squared_error: 0.8072
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.6691 - root_mean_squared_error: 0.8169
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.6727 - root_mean_squared_error: 0.8193
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.6468 - root_mean_squared_error: 0.8040 - val_loss: 0.5614 - val_root_mean_squared_error: 0.7492
#
# Epoch 3/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3502 - root_mean_squared_error: 0.5918
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.4070 - root_mean_squared_error: 0.6364
#  5/49 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.4619 - root_mean_squared_error: 0.6782
#  3/49 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.4354 - root_mean_squared_error: 0.6782
#  4/49 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.4523 - root_mean_squared_error: 0.6782
#  6/49 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.4718 - root_mean_squared_error: 0.6909
#  7/49 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.4792 - root_mean_squared_error: 0.6909
#  9/49 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.4962 - root_mean_squared_error: 0.7097
#  8/49 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.4996 - root_mean_squared_error: 0.7059
# 10/49 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.4933 - root_mean_squared_error: 0.7059
# 12/49 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.5067 - root_mean_squared_error: 0.7111
# 11/49 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.5049 - root_mean_squared_error: 0.7111
# 13/49 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.5082 - root_mean_squared_error: 0.7132
# 14/49 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.5097 - root_mean_squared_error: 0.7132
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.5425 - root_mean_squared_error: 0.7361 - val_loss: 0.5207 - val_root_mean_squared_error: 0.7216
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5126 - root_mean_squared_error: 0.7159
#  2/13 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.5024 - root_mean_squared_error: 0.7087
#  3/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.5148 - root_mean_squared_error: 0.7174
#  4/13 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 0.5122 - root_mean_squared_error: 0.7156
#  5/13 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.5125 - root_mean_squared_error: 0.7158
#  6/13 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - loss: 0.5093 - root_mean_squared_error: 0.7136
#  7/13 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.5048 - root_mean_squared_error: 0.7104
#  8/13 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - loss: 0.5040 - root_mean_squared_error: 0.7101
#  9/13 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.5043 - root_mean_squared_error: 0.7101
# 11/13 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.5028 - root_mean_squared_error: 0.7090
# 10/13 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.5034 - root_mean_squared_error: 0.7094
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5054 - root_mean_squared_error: 0.7109
#
# 100%|██████████| 4/4 [00:20<00:00,  5.13s/trial, best loss: 0.7215794324874878]
# Best parameters: {'lr': 0.016308192329108056, 'momentum': 0.8315217906802983}
# Best rmse: 0.7215794324874878
